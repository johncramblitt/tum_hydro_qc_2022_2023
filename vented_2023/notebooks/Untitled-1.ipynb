# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lyellMC = pd.read_csv(r"output\processed_data\LyellBlwMaclure_timeseries_stage_Q_T_2004_2023.csv",index_col=[0],parse_dates=[0])
dana = pd.read_csv(r"output\processed_data\DanaFk@BugCamp_timeseries_stage_Q_T_2005_2023.csv",index_col=[0],parse_dates=[0])
tum = pd.read_csv(r"output\processed_data\Tuolumne@120_timeseries_stage_Q_T_2001_2023.csv",index_col=[0],parse_dates=[0])
lyellTB = pd.read_csv(r"output\processed_data\LyellAbvTB_timeseries_stage_Q_T_2005_2023.csv",index_col=[0],parse_dates=[0])

# %%
fig, ax = plt.subplots()
ax.plot(lyellMC['estimated_discharge(cms)'],label='MC',c='red')
ax.plot(dana['estimated_discharge(cms)'],label='dana')
ax.plot(lyellTB['estimated_discharge(cms)'],label='dana')

ax.legend()
ax.set_xlim()
# Out:
# (-16746.600000000002, 351678.6)
# Error in callback <function _draw_all_if_interactive at 0x000001F550BFCE00> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\johnc\miniforge3\envs\tuolumne\Lib\site-packages\matplotlib\pyplot.py:278, in _draw_all_if_interactive()
#     276 def _draw_all_if_interactive() -> None:
#     277     if matplotlib.is_interactive():
# --> 278         draw_all()
#
# File c:\Users\johnc\miniforge3\envs\tuolumne\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# ...
